# %%
import random
import math


def roll_dice(random, number_of_rolls= 6, sides_on_die=6, start_at=0):
    '''
        Simulate a normal distribution of values through a dice simulator
    '''
    total = 0
    for i in range(number_of_rolls):
        total += random.randint(start_at,sides_on_die-1+start_at)
    return total

def gen_dice(max_buckets, widest_normal_dist=True):
    '''
        Input the number of buckets and the whether you want a wide or narrow distribution and you 
        will get back the required arguments to roll dice
    '''
    n = max_buckets - 1
    if widest_normal_dist==True:
        for i in range(int(math.sqrt(n)),1,-1):
            if n%i == 0:
                break        
    else:
        for i in range(2,n+1):
            if n%i == 0:
                break

    rolls = n//i
    sides = i+1
    return rolls, sides

def rand_normal_dist(random, n, widest_normal_dist=True):
    '''
        Get a random number between 0 and n, using a standard normal disribution.
        widest_normal_dist=True will use the widest distribuion possible (larger std)
    '''
    rolls,sides = gen_dice(n,widest_normal_dist);
    return roll_dice(random,rolls, sides,0)



def ssh_gen(count):
    '''
    Generate count number of unique social-security numbers
    '''    
    prefix = list(range(1000))
    middle = list(range(100))
    suffix = list(range(10000))
    numbers = []
    random.shuffle(prefix)
    random.shuffle(middle)
    random.shuffle(suffix)    
    for i in range(count):
        p = random.choice(prefix)
        m = random.choice(middle)
        s = suffix.pop()
        number = f"{p:03}-{m:02}-{s:04}"
        numbers.append(number)
    return numbers

# %%
import json
ssn = ssh_gen(235)
with open ('seeddata/funny-person.json') as f:
    people = json.load(f)
    
for i in range(len(people)):
    people[i]['ssn'] = ssn[i]
    people[i]['_key'] = ssn[i]

people
# Out:
# [{'_key': '515-62-5368',
#   'email': 'akuss@armyspy.com',
#   'first_name': 'Abby',
#   'last_name': 'Kuss',
#   'ssn': '515-62-5368'},
#  {'_key': '781-00-9353',
#   'email': 'aantium87@dayrep.com',
#   'first_name': 'Adam',
#   'last_name': 'Antium',
#   'ssn': '781-00-9353'},
#  {'_key': '559-55-4706',
#   'email': 'aowse@dayrep.com',
#   'first_name': 'Addie',
#   'last_name': 'Owse',
#   'ssn': '559-55-4706'},
#  {'_key': '533-92-2796',
#   'email': 'asomewun17@einrot.com',
#   'first_name': 'Aiden',
#   'last_name': 'Somewun',
#   'ssn': '533-92-2796'},
#  {'_key': '369-37-9012',
#   'email': 'aknowone28@gustr.com',
#   'first_name': 'Aiden',
#   'last_name': 'Knowone',
#   'ssn': '369-37-9012'},
#  {'_key': '056-62-8945',
#   'email': 'afrecso@dayrep.com',
#   'first_name': 'Al',
#   'last_name': 'Frecso',
#   'ssn': '056-62-8945'},
#  {'_key': '573-00-7626',
#   'email': 'akohol@rhyta.com',
#   'first_name': 'Al',
#   'last_name': 'Kohol',
#   'ssn': '573-00-7626'},
#  {'_key': '603-25-3416',
#   'email': 'allan.wrench@dayrep.com',
#   'first_name': 'Allan',
#   'last_name': 'Wrench',
#   'ssn': '603-25-3416'},
#  {'_key': '140-63-5030',
#   'email': 'agator@dayrep.com',
#   'first_name': 'Ally',
#   'last_name': 'Gator',
#   'ssn': '140-63-5030'},
#  {'_key': '777-43-2728',
#   'email': 'alma.frienzergon@dayrep.com',
#   'first_name': 'Alma',
#   'last_name': 'Frienzergon',
#   'ssn': '777-43-2728'},
#  {'_key': '253-27-5673',
#   'email': 'amanda.hugginkiss@armyspy.com',
#   'first_name': 'Amanda',
#   'last_name': 'Hugginkiss',
#   'ssn': '253-27-5673'},
#  {'_key': '958-76-7513',
#   'email': 'awavesofgrain@dayrep.com',
#   'first_name': 'Amber',
#   'last_name': 'Wavesofgrain',
#   'ssn': '958-76-7513'},
#  {'_key': '539-80-4459',
#   'email': 'ajob@armyspy.com',
#   'first_name': 'Anita',
#   'last_name': 'Job',
#   'ssn': '539-80-4459'},
#  {'_key': '415-79-2532',
#   'email': 'afavor55@armyspy.com',
#   'first_name': 'Anita',
#   'last_name': 'Favor',
#   'ssn': '415-79-2532'},
#  {'_key': '697-65-0170',
#   'email': 'anita.shower@superrito.com',
#   'first_name': 'Anita',
#   'last_name': 'Shower',
#   'ssn': '697-65-0170'},
#  {'_key': '778-63-2969',
#   'email': 'anita.sandwich@einrot.com',
#   'first_name': 'Anita',
#   'last_name': 'Sandwich',
#   'ssn': '778-63-2969'},
#  {'_key': '449-29-8961',
#   'email': 'adewey@rhyta.com',
#   'first_name': 'Anne',
#   'last_name': 'Dewey',
#   'ssn': '449-29-8961'},
#  {'_key': '685-84-9242',
#   'email': 'afirst99@dayrep.com',
#   'first_name': 'April',
#   'last_name': 'First',
#   'ssn': '685-84-9242'},
#  {'_key': '923-48-2864',
#   'email': 'arial.photo@dayrep.com',
#   'first_name': 'Arial',
#   'last_name': 'Photo',
#   'ssn': '923-48-2864'},
#  {'_key': '121-56-1399',
#   'email': 'asurvellence@einrot.com',
#   'first_name': 'Arial',
#   'last_name': 'Survellence',
#   'ssn': '121-56-1399'},
#  {'_key': '520-62-3750',
#   'email': 'achoke@superrito.com',
#   'first_name': 'Artie',
#   'last_name': 'Choke',
#   'ssn': '520-62-3750'},
#  {'_key': '964-09-8650',
#   'email': 'aborealis93@superrito.com',
#   'first_name': 'Aurora',
#   'last_name': 'Borealis',
#   'ssn': '964-09-8650'},
#  {'_key': '904-96-6707',
#   'email': 'bdwyer76@rhyta.com',
#   'first_name': 'Barb',
#   'last_name': 'Dwyer',
#   'ssn': '904-96-6707'},
#  {'_key': '881-48-2053',
#   'email': 'bbarion@armyspy.com',
#   'first_name': 'Barb',
#   'last_name': 'Barion',
#   'ssn': '881-48-2053'},
#  {'_key': '885-65-8247',
#   'email': 'bdehatchett52@gustr.com',
#   'first_name': 'Barry',
#   'last_name': 'DeHatchett',
#   'ssn': '885-65-8247'},
#  {'_key': '002-69-6266',
#   'email': 'bmii@superrito.com',
#   'first_name': 'Barry',
#   'last_name': 'Mii',
#   'ssn': '002-69-6266'},
#  {'_key': '607-57-5684',
#   'email': 'bleif@gustr.com',
#   'first_name': 'Basil',
#   'last_name': 'Leif',
#   'ssn': '607-57-5684'},
#  {'_key': '581-41-4823',
#   'email': 'balott@einrot.com',
#   'first_name': 'Bette',
#   'last_name': 'Alott',
#   'ssn': '581-41-4823'},
#  {'_key': '450-24-3116',
#   'email': 'bette.itall@superrito.com',
#   'first_name': 'Bette',
#   'last_name': 'Itall',
#   'ssn': '450-24-3116'},
#  {'_key': '942-65-3816',
#   'email': 'bmelator@superrito.com',
#   'first_name': 'Bill',
#   'last_name': 'Melator',
#   'ssn': '942-65-3816'},
#  {'_key': '738-93-9070',
#   'email': 'bislate@dayrep.com',
#   'first_name': 'Bill',
#   'last_name': 'Islate',
#   'ssn': '738-93-9070'},
#  {'_key': '071-66-9248',
#   'email': 'bdalmonds@superrito.com',
#   'first_name': 'Blanche',
#   'last_name': 'Dalmonds',
#   'ssn': '071-66-9248'},
#  {'_key': '265-16-2070',
#   'email': 'benarreau@superrito.com',
#   'first_name': 'Bo',
#   'last_name': 'Enarreau',
#   'ssn': '265-16-2070'},
#  {'_key': '189-32-2043',
#   'email': 'benweave73@superrito.com',
#   'first_name': 'Bob',
#   'last_name': 'Enweave',
#   'ssn': '189-32-2043'},
#  {'_key': '644-44-2632',
#   'email': 'byourhair@dayrep.com',
#   'first_name': 'Brayden',
#   'last_name': 'Yourhair',
#   'ssn': '644-44-2632'},
#  {'_key': '998-42-5975',
#   'email': 'bhair@armyspy.com',
#   'first_name': 'Brayden',
#   'last_name': 'Hair',
#   'ssn': '998-42-5975'},
#  {'_key': '199-26-3631',
#   'email': 'bnaked69@superrito.com',
#   'first_name': 'Buck',
#   'last_name': 'Naked',
#   'ssn': '199-26-3631'},
#  {'_key': '426-10-1853',
#   'email': 'buck.annaquarter@superrito.com',
#   'first_name': 'Buck',
#   'last_name': 'Annaquarter',
#   'ssn': '426-10-1853'},
#  {'_key': '324-26-5765',
#   'email': 'ccorder@gustr.com',
#   'first_name': 'Cam',
#   'last_name': 'Corder',
#   'ssn': '324-26-5765'},
#  {'_key': '423-81-0912',
#   'email': 'cpayne54@dayrep.com',
#   'first_name': 'Cam',
#   'last_name': 'Payne',
#   'ssn': '423-81-0912'},
#  {'_key': '403-23-1996',
#   'email': 'crha@superrito.com',
#   'first_name': 'Cam',
#   'last_name': 'Rha',
#   'ssn': '403-23-1996'},
#  {'_key': '591-22-7643',
#   'email': 'cdryve50@gustr.com',
#   'first_name': 'Carmen',
#   'last_name': 'Dryve',
#   'ssn': '591-22-7643'},
#  {'_key': '989-69-3061',
#   'email': 'ckane36@dayrep.com',
#   'first_name': 'Candi',
#   'last_name': 'Kane',
#   'ssn': '989-69-3061'},
#  {'_key': '990-75-8528',
#   'email': 'candi.dish@dayrep.com',
#   'first_name': 'Candi',
#   'last_name': 'Dish',
#   'ssn': '990-75-8528'},
#  {'_key': '489-42-0677',
#   'email': 'cling@dayrep.com',
#   'first_name': 'Carol',
#   'last_name': 'Ling',
#   'ssn': '489-42-0677'},
#  {'_key': '721-62-7502',
#   'email': 'cdababbi@einrot.com',
#   'first_name': 'Carrie',
#   'last_name': 'Dababbi',
#   'ssn': '721-62-7502'},
#  {'_key': '271-17-9979',
#   'email': 'cmeehom72@dayrep.com',
#   'first_name': 'Carrie',
#   'last_name': 'Meehom',
#   'ssn': '271-17-9979'},
#  {'_key': '268-56-6876',
#   'email': 'csalad@armyspy.com',
#   'first_name': 'Cesar',
#   'last_name': 'Salad',
#   'ssn': '268-56-6876'},
#  {'_key': '138-77-4994',
#   'email': 'chase.lounge@gustr.com',
#   'first_name': 'Chase',
#   'last_name': 'Lounge',
#   'ssn': '138-77-4994'},
#  {'_key': '922-57-4632',
#   'email': 'cpeanugget@gustr.com',
#   'first_name': 'Chris',
#   'last_name': 'Peanugget',
#   'ssn': '922-57-4632'},
#  {'_key': '168-37-3649',
#   'email': 'chuck.itupp@superrito.com',
#   'first_name': 'Chuck',
#   'last_name': 'Itupp',
#   'ssn': '168-37-3649'},
#  {'_key': '552-84-4562',
#   'email': 'cpotts@gustr.com',
#   'first_name': 'Clay',
#   'last_name': 'Potts',
#   'ssn': '552-84-4562'},
#  {'_key': '565-48-1437',
#   'email': 'clifton.owhere@rhyta.com',
#   'first_name': 'Clifton',
#   'last_name': 'Owhere',
#   'ssn': '565-48-1437'},
#  {'_key': '122-60-4857',
#   'email': 'cole.deggs@rhyta.com',
#   'first_name': 'Cole',
#   'last_name': 'Deggs',
#   'ssn': '122-60-4857'},
#  {'_key': '111-56-7793',
#   'email': 'cook.myefoud@superrito.com',
#   'first_name': 'Cook',
#   'last_name': 'Myefoud',
#   'ssn': '111-56-7793'},
#  {'_key': '459-74-4608',
#   'email': 'cchocolate@superrito.com',
#   'first_name': 'Craven',
#   'last_name': 'Chocolate',
#   'ssn': '459-74-4608'},
#  {'_key': '192-66-1366',
#   'email': 'ccleer@superrito.com',
#   'first_name': 'Crystal',
#   'last_name': 'Cleer',
#   'ssn': '192-66-1366'},
#  {'_key': '373-57-9678',
#   'email': 'crystal.ball@superrito.com',
#   'first_name': 'Crystal',
#   'last_name': 'Ball',
#   'ssn': '373-57-9678'},
#  {'_key': '319-99-8418',
#   'email': 'dean.ofstudents@einrot.com',
#   'first_name': 'Dean',
#   'last_name': 'Ofstudents',
#   'ssn': '319-99-8418'},
#  {'_key': '716-44-7134',
#   'email': 'ddelyons@rhyta.com',
#   'first_name': 'Dan',
#   'last_name': 'Delyons',
#   'ssn': '716-44-7134'},
#  {'_key': '645-07-9505',
#   'email': 'dinator@superrito.com',
#   'first_name': 'Dom',
#   'last_name': 'Inator',
#   'ssn': '645-07-9505'},
#  {'_key': '321-52-1883',
#   'email': 'dclosed79@superrito.com',
#   'first_name': 'Doris',
#   'last_name': 'Closed',
#   'ssn': '321-52-1883'},
#  {'_key': '736-73-6252',
#   'email': 'dnolongeropen76@dayrep.com',
#   'first_name': 'Doris',
#   'last_name': 'Nolongeropen',
#   'ssn': '736-73-6252'},
#  {'_key': '531-22-3951',
#   'email': 'dapicture@dayrep.com',
#   'first_name': 'Drew',
#   'last_name': 'Apicture',
#   'ssn': '531-22-3951'},
#  {'_key': '691-27-5449',
#   'email': 'ddewinned02@dayrep.com',
#   'first_name': 'Dustin',
#   'last_name': 'DeWinned',
#   'ssn': '691-27-5449'},
#  {'_key': '258-98-7598',
#   'email': 'etoudawright@armyspy.com',
#   'first_name': 'Eileen',
#   'last_name': 'Touda-Wright',
#   'ssn': '258-98-7598'},
#  {'_key': '363-47-6635',
#   'email': 'eileen.toudaleft@einrot.com',
#   'first_name': 'Eileen',
#   'last_name': 'Touda-Left',
#   'ssn': '363-47-6635'},
#  {'_key': '997-13-8621',
#   'email': 'elieen.onyewe@gustr.com',
#   'first_name': 'Elieen',
#   'last_name': 'Onyewe',
#   'ssn': '997-13-8621'},
#  {'_key': '469-19-4101',
#   'email': 'edetyers@gustr.com',
#   'first_name': 'Erin',
#   'last_name': 'Detyers',
#   'ssn': '469-19-4101'},
#  {'_key': '959-27-3908',
#   'email': 'eyortires@gustr.com',
#   'first_name': 'Erin',
#   'last_name': 'Yortires',
#   'ssn': '959-27-3908'},
#  {'_key': '404-14-7985',
#   'email': 'equittin33@dayrep.com',
#   'first_name': 'Eura',
#   'last_name': 'Quittin',
#   'ssn': '404-14-7985'},
#  {'_key': '495-41-3173',
#   'email': 'elyre@gustr.com',
#   'first_name': 'Eura',
#   'last_name': 'Lyre',
#   'ssn': '495-41-3173'},
#  {'_key': '090-66-7600',
#   'email': 'etasomthin@rhyta.com',
#   'first_name': 'Euron',
#   'last_name': 'Tasomthin',
#   'ssn': '090-66-7600'},
#  {'_key': '921-76-2688',
#   'email': 'efyre@einrot.com',
#   'first_name': 'Euron',
#   'last_name': 'Fyre',
#   'ssn': '921-76-2688'},
#  {'_key': '188-64-2144',
#   'email': 'ffurter@superrito.com',
#   'first_name': 'Frank',
#   'last_name': 'Furter',
#   'ssn': '188-64-2144'},
#  {'_key': '150-80-4134',
#   'email': 'frank.klee@gustr.com',
#   'first_name': 'Frank',
#   'last_name': 'Klee',
#   'ssn': '150-80-4134'},
#  {'_key': '084-91-2754',
#   'email': 'gforcewynds@gustr.com',
#   'first_name': 'Gail',
#   'last_name': 'Forcewynds',
#   'ssn': '084-91-2754'},
#  {'_key': '277-33-6106',
#   'email': 'gmoore@armyspy.com',
#   'first_name': 'Gamble',
#   'last_name': 'Moore',
#   'ssn': '277-33-6106'},
#  {'_key': '035-31-1742',
#   'email': 'gling96@rhyta.com',
#   'first_name': 'Gamble',
#   'last_name': 'Ling',
#   'ssn': '035-31-1742'},
#  {'_key': '598-88-6830',
#   'email': 'ginger.snaps@armyspy.com',
#   'first_name': 'Ginger',
#   'last_name': 'Snaps',
#   'ssn': '598-88-6830'},
#  {'_key': '197-38-8981',
#   'email': 'ginger.beer@dayrep.com',
#   'first_name': 'Ginger',
#   'last_name': 'Beer',
#   'ssn': '197-38-8981'},
#  {'_key': '638-22-3313',
#   'email': 'gtoffwind@gustr.com',
#   'first_name': 'Gus',
#   'last_name': 'Toffwind',
#   'ssn': '638-22-3313'},
#  {'_key': '706-07-9366',
#   'email': 'herchief@einrot.com',
#   'first_name': 'Hank',
#   'last_name': 'Erchief',
#   'ssn': '706-07-9366'},
#  {'_key': '731-69-3069',
#   'email': 'harry.pits@dayrep.com',
#   'first_name': 'Harry',
#   'last_name': 'Pits',
#   'ssn': '731-69-3069'},
#  {'_key': '029-51-0463',
#   'email': 'harry.face@gustr.com',
#   'first_name': 'Harry',
#   'last_name': 'Face',
#   'ssn': '029-51-0463'},
#  {'_key': '745-80-2669',
#   'email': 'heyes@einrot.com',
#   'first_name': 'Hazel',
#   'last_name': 'Eyes',
#   'ssn': '745-80-2669'},
#  {'_key': '625-23-8336',
#   'email': 'hbarr12@gustr.com',
#   'first_name': 'Heath',
#   'last_name': 'Barr',
#   'ssn': '625-23-8336'},
#  {'_key': '106-08-2828',
#   'email': 'heywood.yamind@dayrep.com',
#   'first_name': 'Heywood',
#   'last_name': 'Yamind',
#   'ssn': '106-08-2828'},
#  {'_key': '990-20-4425',
#   'email': 'hstrong@einrot.com',
#   'first_name': 'Holden',
#   'last_name': 'Strong',
#   'ssn': '990-20-4425'},
#  {'_key': '397-43-9943',
#   'email': 'hyorenose@gustr.com',
#   'first_name': 'Holden',
#   'last_name': 'Yorenose',
#   'ssn': '397-43-9943'},
#  {'_key': '093-29-8015',
#   'email': 'hjapple@rhyta.com',
#   'first_name': 'Hugh',
#   'last_name': 'Japple',
#   'ssn': '093-29-8015'},
#  {'_key': '355-37-7091',
#   'email': 'ian.ewe@superrito.com',
#   'first_name': 'Ian',
#   'last_name': 'Ewe',
#   'ssn': '355-37-7091'},
#  {'_key': '566-80-6168',
#   'email': 'ida.knowe@dayrep.com',
#   'first_name': 'Ida',
#   'last_name': 'Knowe',
#   'ssn': '566-80-6168'},
#  {'_key': '137-92-4533',
#   'email': 'isabelle.gunnering@armyspy.com',
#   'first_name': 'Isabelle',
#   'last_name': 'Gunnering',
#   'ssn': '137-92-4533'},
#  {'_key': '621-81-7042',
#   'email': 'iringing35@armyspy.com',
#   'first_name': 'Isabelle',
#   'last_name': 'Ringing',
#   'ssn': '621-81-7042'},
#  {'_key': '875-41-8653',
#   'email': 'istuckopen@einrot.com',
#   'first_name': 'Isadore',
#   'last_name': 'Stuckopen',
#   'ssn': '875-41-8653'},
#  {'_key': '481-46-2587',
#   'email': 'ijammed@superrito.com',
#   'first_name': 'Isadore',
#   'last_name': 'Jammed',
#   'ssn': '481-46-2587'},
#  {'_key': '519-06-1867',
#   'email': 'iornotte@einrot.com',
#   'first_name': 'Isreal',
#   'last_name': 'Ornotte',
#   'ssn': '519-06-1867'},
#  {'_key': '401-35-1556',
#   'email': 'isreal.difficult@rhyta.com',
#   'first_name': 'Isreal',
#   'last_name': 'Difficult',
#   'ssn': '401-35-1556'},
#  {'_key': '084-54-5658',
#   'email': 'isandwich@dayrep.com',
#   'first_name': 'Ivana',
#   'last_name': 'Sandwich',
#   'ssn': '084-54-5658'},
#  {'_key': '733-30-8645',
#   'email': 'jack.itupp@gustr.com',
#   'first_name': 'Jack',
#   'last_name': 'Itupp',
#   'ssn': '733-30-8645'},
#  {'_key': '962-74-1277',
#   'email': 'jolantern53@superrito.com',
#   'first_name': 'Jack',
#   'last_name': "O'Lantern",
#   'ssn': '962-74-1277'},
#  {'_key': '580-04-4817',
#   'email': 'jpoole@dayrep.com',
#   'first_name': 'Jean',
#   'last_name': 'Poole',
#   'ssn': '580-04-4817'},
#  {'_key': '151-82-5640',
#   'email': 'jnetics@gustr.com',
#   'first_name': 'Jin',
#   'last_name': 'Netics',
#   'ssn': '151-82-5640'},
#  {'_key': '780-85-4263',
#   'email': 'joanne.bill@armyspy.com',
#   'first_name': 'Joanne',
#   'last_name': 'Bill',
#   'ssn': '780-85-4263'},
#  {'_key': '693-20-9106',
#   'email': 'jking46@rhyta.com',
#   'first_name': 'Joe',
#   'last_name': 'King',
#   'ssn': '693-20-9106'},
#  {'_key': '813-76-8243',
#   'email': 'jczonou15@armyspy.com',
#   'first_name': 'Joe',
#   'last_name': 'Czonou',
#   'ssn': '813-76-8243'},
#  {'_key': '047-33-0921',
#   'email': 'jtoudaworld@dayrep.com',
#   'first_name': 'Joy',
#   'last_name': 'Touda-World',
#   'ssn': '047-33-0921'},
#  {'_key': '821-88-4450',
#   'email': 'jfulle@gustr.com',
#   'first_name': 'Joy',
#   'last_name': 'Fulle',
#   'ssn': '821-88-4450'},
#  {'_key': '951-26-6435',
#   'email': 'jbugg82@superrito.com',
#   'first_name': 'June',
#   'last_name': 'Bugg',
#   'ssn': '951-26-6435'},
#  {'_key': '991-56-0931',
#   'email': 'jnipper@gustr.com',
#   'first_name': 'June',
#   'last_name': 'Nipper',
#   'ssn': '991-56-0931'},
#  {'_key': '116-76-3974',
#   'email': 'jcase65@gustr.com',
#   'first_name': 'Justin',
#   'last_name': 'Case',
#   'ssn': '116-76-3974'},
#  {'_key': '027-59-3565',
#   'email': 'jthyme01@einrot.com',
#   'first_name': 'Justin',
#   'last_name': 'Thyme',
#   'ssn': '027-59-3565'},
#  {'_key': '114-23-3746',
#   'email': 'karen.less@einrot.com',
#   'first_name': 'Karen',
#   'last_name': 'Less',
#   'ssn': '114-23-3746'},
#  {'_key': '730-89-9449',
#   'email': 'kpasdcourse@gustr.com',
#   'first_name': 'Kenny',
#   'last_name': "Pas-D'course",
#   'ssn': '730-89-9449'},
#  {'_key': '544-91-7578',
#   'email': 'kdoit37@gustr.com',
#   'first_name': 'Kenny',
#   'last_name': 'Doit',
#   'ssn': '544-91-7578'},
#  {'_key': '655-52-9508',
#   'email': 'kbelevit56@einrot.com',
#   'first_name': 'Kent',
#   'last_name': 'Belevit',
#   'ssn': '655-52-9508'},
#  {'_key': '934-66-6867',
#   'email': 'kkat@dayrep.com',
#   'first_name': 'Kitty',
#   'last_name': 'Kat',
#   'ssn': '934-66-6867'},
#  {'_key': '846-23-7442',
#   'email': 'kurt.tain@gustr.com',
#   'first_name': 'Kurt',
#   'last_name': 'Tain',
#   'ssn': '846-23-7442'},
#  {'_key': '956-42-2622',
#   'email': 'lhvmeehom@armyspy.com',
#   'first_name': 'Lee',
#   'last_name': 'Hvmeehom',
#   'ssn': '956-42-2622'},
#  {'_key': '233-52-1663',
#   'email': 'lismoore@dayrep.com',
#   'first_name': 'Les',
#   'last_name': 'Ismoore',
#   'ssn': '233-52-1663'},
#  {'_key': '100-00-6163',
#   'email': 'les.tocleanup@dayrep.com',
#   'first_name': 'Les',
#   'last_name': 'Tocleanup',
#   'ssn': '100-00-6163'},
#  {'_key': '586-04-4981',
#   'email': 'lmeehom@dayrep.com',
#   'first_name': 'Leiv',
#   'last_name': 'Meehom',
#   'ssn': '586-04-4981'},
#  {'_key': '579-29-6079',
#   'email': 'lamess@superrito.com',
#   'first_name': 'Leiv',
#   'last_name': 'Amess',
#   'ssn': '579-29-6079'},
#  {'_key': '201-56-9564',
#   'email': 'lilly.padz@dayrep.com',
#   'first_name': 'Lilly',
#   'last_name': 'Padz',
#   'ssn': '201-56-9564'},
#  {'_key': '161-76-0353',
#   'email': 'lisa.karfurless@rhyta.com',
#   'first_name': 'Lisa',
#   'last_name': 'Karfurless',
#   'ssn': '161-76-0353'},
#  {'_key': '086-45-9695',
#   'email': 'ldabridgeda@rhyta.com',
#   'first_name': 'Lola',
#   'last_name': 'Dabridgeda',
#   'ssn': '086-45-9695'},
#  {'_key': '299-90-9258',
#   'email': 'lmedowne@superrito.com',
#   'first_name': 'Loren',
#   'last_name': 'Medowne',
#   'ssn': '299-90-9258'},
#  {'_key': '722-44-7506',
#   'email': 'ldabucket@dayrep.com',
#   'first_name': 'Loren',
#   'last_name': 'Dabucket',
#   'ssn': '722-44-7506'},
#  {'_key': '551-43-3729',
#   'email': 'lenne@gustr.com',
#   'first_name': 'Luther',
#   'last_name': 'Enne',
#   'ssn': '551-43-3729'},
#  {'_key': '890-71-9425',
#   'email': 'mitdowne44@einrot.com',
#   'first_name': 'Mark',
#   'last_name': 'Itdowne',
#   'ssn': '890-71-9425'},
#  {'_key': '662-53-3065',
#   'email': 'msmann@armyspy.com',
#   'first_name': 'Mark',
#   'last_name': 'Smann',
#   'ssn': '662-53-3065'},
#  {'_key': '527-51-8481',
#   'email': 'meyezing19@gustr.com',
#   'first_name': 'Martin',
#   'last_name': 'Eyezing',
#   'ssn': '527-51-8481'},
#  {'_key': '166-28-7847',
#   'email': 'mary.melator@gustr.com',
#   'first_name': 'Mary',
#   'last_name': 'Melator',
#   'ssn': '166-28-7847'},
#  {'_key': '635-04-6283',
#   'email': 'mmi@gustr.com',
#   'first_name': 'Mary',
#   'last_name': 'Mi',
#   'ssn': '635-04-6283'},
#  {'_key': '721-50-3930',
#   'email': 'mfur61@superrito.com',
#   'first_name': 'Mattie',
#   'last_name': 'Fur',
#   'ssn': '721-50-3930'},
#  {'_key': '893-26-0616',
#   'email': 'marronne07@dayrep.com',
#   'first_name': 'Mac',
#   'last_name': 'Arronne',
#   'ssn': '893-26-0616'},
#  {'_key': '995-78-2342',
#   'email': 'mdonalds@rhyta.com',
#   'first_name': 'Mac',
#   'last_name': 'Donalds',
#   'ssn': '995-78-2342'},
#  {'_key': '104-82-8319',
#   'email': 'mintosh@dayrep.com',
#   'first_name': 'Mac',
#   'last_name': 'Intosh',
#   'ssn': '104-82-8319'},
#  {'_key': '867-39-4151',
#   'email': 'mday40@armyspy.com',
#   'first_name': 'May',
#   'last_name': 'Day',
#   'ssn': '867-39-4151'},
#  {'_key': '182-78-1811',
#   'email': 'mflies57@rhyta.com',
#   'first_name': 'May',
#   'last_name': 'Flies',
#   'ssn': '182-78-1811'},
#  {'_key': '809-65-1116',
#   'email': 'mimumm94@dayrep.com',
#   'first_name': 'Max',
#   'last_name': 'Imumm',
#   'ssn': '809-65-1116'},
#  {'_key': '225-51-9772',
#   'email': 'mrophone@armyspy.com',
#   'first_name': 'Mike',
#   'last_name': 'Rophone',
#   'ssn': '225-51-9772'},
#  {'_key': '273-86-4648',
#   'email': 'mdupp79@gustr.com',
#   'first_name': 'Mike',
#   'last_name': 'Dupp',
#   'ssn': '273-86-4648'},
#  {'_key': '407-27-3291',
#   'email': 'minnie.aturedoberman@superrito.com',
#   'first_name': 'Minnie',
#   'last_name': 'Ature-Doberman',
#   'ssn': '407-27-3291'},
#  {'_key': '041-48-3728',
#   'email': 'mmeadows@superrito.com',
#   'first_name': 'Misty',
#   'last_name': 'Meadows',
#   'ssn': '041-48-3728'},
#  {'_key': '873-58-7345',
#   'email': 'mshores@dayrep.com',
#   'first_name': 'Misty',
#   'last_name': 'Shores',
#   'ssn': '873-58-7345'},
#  {'_key': '291-56-0374',
#   'email': 'mless@gustr.com',
#   'first_name': 'Morris',
#   'last_name': 'Less',
#   'ssn': '291-56-0374'},
#  {'_key': '203-71-1878',
#   'email': 'myra.sisdone@einrot.com',
#   'first_name': 'Myra',
#   'last_name': 'Sisdone',
#   'ssn': '203-71-1878'},
#  {'_key': '143-95-3205',
#   'email': 'ntural39@dayrep.com',
#   'first_name': 'Nat',
#   'last_name': 'Tural',
#   'ssn': '143-95-3205'},
#  {'_key': '518-21-8678',
#   'email': 'nturallie@dayrep.com',
#   'first_name': 'Nat',
#   'last_name': 'Turallie',
#   'ssn': '518-21-8678'},
#  {'_key': '451-19-1708',
#   'email': 'neil.downe@dayrep.com',
#   'first_name': 'Neil',
#   'last_name': 'Downe',
#   'ssn': '451-19-1708'},
#  {'_key': '562-53-7040',
#   'email': 'nofthyme63@rhyta.com',
#   'first_name': 'Nick',
#   'last_name': 'Ofthyme',
#   'ssn': '562-53-7040'},
#  {'_key': '044-36-9188',
#   'email': 'ostuffismission@einrot.com',
#   'first_name': 'Oliver',
#   'last_name': 'Stuffismission',
#   'ssn': '044-36-9188'},
#  {'_key': '436-36-1093',
#   'email': 'othingz@gustr.com',
#   'first_name': 'Oliver',
#   'last_name': 'Thingz',
#   'ssn': '436-36-1093'},
#  {'_key': '369-10-7501',
#   'email': 'oren.jouglad@gustr.com',
#   'first_name': 'Oren',
#   'last_name': 'Jouglad',
#   'ssn': '369-10-7501'},
#  {'_key': '678-51-5677',
#   'email': 'otto.moni@armyspy.com',
#   'first_name': 'Otto',
#   'last_name': 'Moni',
#   'ssn': '678-51-5677'},
#  {'_key': '311-58-3538',
#   'email': 'othyme@rhyta.com',
#   'first_name': 'Otto',
#   'last_name': 'Thyme',
#   'ssn': '311-58-3538'},
#  {'_key': '031-18-4510',
#   'email': 'pofurniture@armyspy.com',
#   'first_name': 'Patty',
#   'last_name': "O'Furniture",
#   'ssn': '031-18-4510'},
#  {'_key': '644-33-9291',
#   'email': 'pobeef@dayrep.com',
#   'first_name': 'Patty',
#   'last_name': "O'Beef",
#   'ssn': '644-33-9291'},
#  {'_key': '882-15-5369',
#   'email': 'ppincher21@dayrep.com',
#   'first_name': 'Penny',
#   'last_name': 'Pincher',
#   'ssn': '882-15-5369'},
#  {'_key': '068-38-3804',
#   'email': 'ploafer28@gustr.com',
#   'first_name': 'Penny',
#   'last_name': 'Loafer',
#   'ssn': '068-38-3804'},
#  {'_key': '112-63-5069',
#   'email': 'pmoss@armyspy.com',
#   'first_name': 'Pete',
#   'last_name': 'Moss',
#   'ssn': '112-63-5069'},
#  {'_key': '655-68-1744',
#   'email': 'pterpan@dayrep.com',
#   'first_name': 'Pete',
#   'last_name': 'Terpan',
#   'ssn': '655-68-1744'},
#  {'_key': '661-38-1539',
#   'email': 'phil.meaup@gustr.com',
#   'first_name': 'Phil',
#   'last_name': 'Meaup',
#   'ssn': '661-38-1539'},
#  {'_key': '069-99-8924',
#   'email': 'phil.italltheweigh@einrot.com',
#   'first_name': 'Phil',
#   'last_name': 'Itall-Theweigh',
#   'ssn': '069-99-8924'},
#  {'_key': '720-49-9994',
#   'email': 'pmccup83@gustr.com',
#   'first_name': 'Phil',
#   'last_name': 'McCup',
#   'ssn': '720-49-9994'},
#  {'_key': '682-20-4001',
#   'email': 'pdtanks@gustr.com',
#   'first_name': 'Philip',
#   'last_name': "D'Tanks",
#   'ssn': '682-20-4001'},
#  {'_key': '038-96-1835',
#   'email': 'rovlight@dayrep.com',
#   'first_name': 'Ray',
#   'last_name': 'Ovlight',
#   'ssn': '038-96-1835'},
#  {'_key': '564-94-1012',
#   'email': 'rtracing@einrot.com',
#   'first_name': 'Ray',
#   'last_name': 'Tracing',
#   'ssn': '564-94-1012'},
#  {'_key': '909-67-3822',
#   'email': 'rcarz@gustr.com',
#   'first_name': 'Rusty',
#   'last_name': 'Carz',
#   'ssn': '909-67-3822'},
#  {'_key': '658-07-9255',
#   'email': 'rnail77@einrot.com',
#   'first_name': 'Rusty',
#   'last_name': 'Nail',
#   'ssn': '658-07-9255'},
#  {'_key': '005-02-5201',
#   'email': 'rip.itupp@rhyta.com',
#   'first_name': 'Rip',
#   'last_name': 'Itupp',
#   'ssn': '005-02-5201'},
#  {'_key': '796-66-2285',
#   'email': 'rcord@rhyta.com',
#   'first_name': 'Rip',
#   'last_name': 'Cord',
#   'ssn': '796-66-2285'},
#  {'_key': '247-43-8727',
#   'email': 'ryerpanz@gustr.com',
#   'first_name': 'Rip',
#   'last_name': 'Yerpanz',
#   'ssn': '247-43-8727'},
#  {'_key': '559-77-4005',
#   'email': 'robin.banks@superrito.com',
#   'first_name': 'Robin',
#   'last_name': 'Banks',
#   'ssn': '559-77-4005'},
#  {'_key': '979-21-3171',
#   'email': 'reue@gustr.com',
#   'first_name': 'Robin',
#   'last_name': 'Eue',
#   'ssn': '979-21-3171'},
#  {'_key': '393-86-8810',
#   'email': 'roland.totowne@einrot.com',
#   'first_name': 'Roland',
#   'last_name': 'Totowne',
#   'ssn': '393-86-8810'},
#  {'_key': '349-14-3628',
#   'email': 'rabovduresst@dayrep.com',
#   'first_name': 'Rose',
#   'last_name': 'Abov-Duresst',
#   'ssn': '349-14-3628'},
#  {'_key': '677-77-0822',
#   'email': 'rtefarian38@gustr.com',
#   'first_name': 'Ross',
#   'last_name': 'Tefarian',
#   'ssn': '677-77-0822'},
#  {'_key': '028-53-1195',
#   'email': 'rdeboat@gustr.com',
#   'first_name': 'Rowan',
#   'last_name': 'Deboat',
#   'ssn': '028-53-1195'},
#  {'_key': '655-82-6474',
#   'email': 'roxanne.gravel@rhyta.com',
#   'first_name': 'Roxanne',
#   'last_name': 'Gravel',
#   'ssn': '655-82-6474'},
#  {'_key': '096-56-3178',
#   'email': 'rstyx@gustr.com',
#   'first_name': 'Roxanne',
#   'last_name': 'Styx',
#   'ssn': '096-56-3178'},
#  {'_key': '855-74-4293',
#   'email': 'rgems@armyspy.com',
#   'first_name': 'Ruby',
#   'last_name': 'Gems',
#   'ssn': '855-74-4293'},
#  {'_key': '695-17-4784',
#   'email': 'rslippers36@rhyta.com',
#   'first_name': 'Ruby',
#   'last_name': 'Slippers',
#   'ssn': '695-17-4784'},
#  {'_key': '666-06-1994',
#   'email': 'rupsomegayme31@gustr.com',
#   'first_name': 'Russel',
#   'last_name': 'Upsome-Gayme',
#   'ssn': '666-06-1994'},
#  {'_key': '336-09-9006',
#   'email': 'sboat@dayrep.com',
#   'first_name': 'Sal',
#   'last_name': 'Boat',
#   'ssn': '336-09-9006'},
#  {'_key': '390-21-0626',
#   'email': 'sdebote@dayrep.com',
#   'first_name': 'Sal',
#   'last_name': 'Debote',
#   'ssn': '390-21-0626'},
#  {'_key': '961-85-9384',
#   'email': 'sal.ladd@gustr.com',
#   'first_name': 'Sal',
#   'last_name': 'Ladd',
#   'ssn': '961-85-9384'},
#  {'_key': '520-97-0381',
#   'email': 'sladdfurdiner28@gustr.com',
#   'first_name': 'Sal',
#   'last_name': 'Ladd-Furdiner',
#   'ssn': '520-97-0381'},
#  {'_key': '161-72-5259',
#   'email': 'smander@rhyta.com',
#   'first_name': 'Sally',
#   'last_name': 'Mander',
#   'ssn': '161-72-5259'},
#  {'_key': '098-24-5706',
#   'email': 'sbeeches@rhyta.com',
#   'first_name': 'Sandy',
#   'last_name': 'Beeches',
#   'ssn': '098-24-5706'},
#  {'_key': '571-69-2924',
#   'email': 'sshores@rhyta.com',
#   'first_name': 'Sandy',
#   'last_name': 'Shores',
#   'ssn': '571-69-2924'},
#  {'_key': '210-13-7074',
#   'email': 'sbellum@rhyta.com',
#   'first_name': 'Sara',
#   'last_name': 'Bellum',
#   'ssn': '210-13-7074'},
#  {'_key': '916-95-3826',
#   'email': 'sdockturindahaus@dayrep.com',
#   'first_name': 'Sara',
#   'last_name': 'Docktur-Indahaus',
#   'ssn': '916-95-3826'},
#  {'_key': '588-69-2775',
#   'email': 'sara.isnomor@superrito.com',
#   'first_name': 'Sara',
#   'last_name': 'Isnomor',
#   'ssn': '588-69-2775'},
#  {'_key': '072-94-3039',
#   'email': 'sofewe20@einrot.com',
#   'first_name': 'Seymour',
#   'last_name': 'Ofewe',
#   'ssn': '072-94-3039'},
#  {'_key': '083-49-9819',
#   'email': 'syerthings@gustr.com',
#   'first_name': 'Sharon',
#   'last_name': 'Yerthings',
#   'ssn': '083-49-9819'},
#  {'_key': '871-62-9809',
#   'email': 'sherry.wyne@dayrep.com',
#   'first_name': 'Sherry',
#   'last_name': 'Wyne',
#   'ssn': '871-62-9809'},
#  {'_key': '269-75-7741',
#   'email': 'smytoyz56@gustr.com',
#   'first_name': 'Sheryl',
#   'last_name': 'Mytoyz',
#   'ssn': '269-75-7741'},
#  {'_key': '499-04-0562',
#   'email': 'shirley.youjest@einrot.com',
#   'first_name': 'Shirley',
#   'last_name': 'Youjest',
#   'ssn': '499-04-0562'},
#  {'_key': '029-97-0709',
#   'email': 'sshores@gustr.com',
#   'first_name': 'Sonny',
#   'last_name': 'Shores',
#   'ssn': '029-97-0709'},
#  {'_key': '695-25-9623',
#   'email': 'sdayz@dayrep.com',
#   'first_name': 'Sonny',
#   'last_name': 'Dayz',
#   'ssn': '695-25-9623'},
#  {'_key': '041-62-2239',
#   'email': 'sskye@gustr.com',
#   'first_name': 'Sonny',
#   'last_name': 'Skye',
#   'ssn': '041-62-2239'},
#  {'_key': '346-63-4859',
#   'email': 'sue.ewe@dayrep.com',
#   'first_name': 'Sue',
#   'last_name': 'Ewe',
#   'ssn': '346-63-4859'},
#  {'_key': '817-49-5922',
#   'email': 'smii@dayrep.com',
#   'first_name': 'Sue',
#   'last_name': 'Mii',
#   'ssn': '817-49-5922'},
#  {'_key': '611-66-1186',
#   'email': 'titupp55@gustr.com',
#   'first_name': 'Tally',
#   'last_name': 'Itupp',
#   'ssn': '611-66-1186'},
#  {'_key': '134-54-5485',
#   'email': 'terry.cloth@armyspy.com',
#   'first_name': 'Terry',
#   'last_name': 'Cloth',
#   'ssn': '134-54-5485'},
#  {'_key': '850-88-6798',
#   'email': 'tera.cotta@armyspy.com',
#   'first_name': 'Tera',
#   'last_name': 'Cotta',
#   'ssn': '850-88-6798'},
#  {'_key': '942-00-1758',
#   'email': 'tera.dactyl@dayrep.com',
#   'first_name': 'Tera',
#   'last_name': 'Dactyl',
#   'ssn': '942-00-1758'},
#  {'_key': '096-96-0269',
#   'email': 'tim.pani@einrot.com',
#   'first_name': 'Tim',
#   'last_name': 'Pani',
#   'ssn': '096-96-0269'},
#  {'_key': '512-08-0512',
#   'email': 'tidd@einrot.com',
#   'first_name': 'Tim',
#   'last_name': 'Idd',
#   'ssn': '512-08-0512'},
#  {'_key': '229-64-7861',
#   'email': 'theo.door@rhyta.com',
#   'first_name': 'Theo',
#   'last_name': 'Door',
#   'ssn': '229-64-7861'},
#  {'_key': '178-66-2185',
#   'email': 'tistrong63@gustr.com',
#   'first_name': 'Theodore',
#   'last_name': 'Istrong',
#   'ssn': '178-66-2185'},
#  {'_key': '820-49-3501',
#   'email': 'tandroll@rhyta.com',
#   'first_name': 'Tuck',
#   'last_name': 'Androll',
#   'ssn': '820-49-3501'},
#  {'_key': '434-67-0804',
#   'email': 'ty.anott@gustr.com',
#   'first_name': 'Ty',
#   'last_name': 'Anott',
#   'ssn': '434-67-0804'},
#  {'_key': '065-13-3208',
#   'email': 'ty.dibol@dayrep.com',
#   'first_name': 'Ty',
#   'last_name': 'Dibol',
#   'ssn': '065-13-3208'},
#  {'_key': '528-59-6392',
#   'email': 'titdowne@dayrep.com',
#   'first_name': 'Ty',
#   'last_name': 'Itdowne',
#   'ssn': '528-59-6392'},
#  {'_key': '159-83-0523',
#   'email': 'vuation60@armyspy.com',
#   'first_name': 'Val',
#   'last_name': 'Uation',
#   'ssn': '159-83-0523'},
#  {'_key': '826-09-9393',
#   'email': 'vidation23@dayrep.com',
#   'first_name': 'Val',
#   'last_name': 'Idation',
#   'ssn': '826-09-9393'},
#  {'_key': '981-61-0538',
#   'email': 'vedance@rhyta.com',
#   'first_name': 'Victor',
#   'last_name': 'Edance',
#   'ssn': '981-61-0538'},
#  {'_key': '065-48-9461',
#   'email': 'vrhee@dayrep.com',
#   'first_name': 'Victor',
#   'last_name': 'Rhee',
#   'ssn': '065-48-9461'},
#  {'_key': '906-91-0223',
#   'email': 'windawater@rhyta.com',
#   'first_name': 'Wade',
#   'last_name': 'Indawater',
#   'ssn': '906-91-0223'},
#  {'_key': '839-53-2249',
#   'email': 'wneedeep@gustr.com',
#   'first_name': 'Wade',
#   'last_name': 'Needeep',
#   'ssn': '839-53-2249'},
#  {'_key': '151-91-9536',
#   'email': 'wpasdcourse@einrot.com',
#   'first_name': 'Willie',
#   'last_name': "Pas-D'course",
#   'ssn': '151-91-9536'},
#  {'_key': '598-40-7509',
#   'email': 'wwork@dayrep.com',
#   'first_name': 'Willie',
#   'last_name': 'Work',
#   'ssn': '598-40-7509'},
#  {'_key': '333-03-1609',
#   'email': 'wsurvive21@armyspy.com',
#   'first_name': 'Willie',
#   'last_name': 'Survive',
#   'ssn': '333-03-1609'},
#  {'_key': '488-26-5727',
#   'email': 'wtree@einrot.com',
#   'first_name': 'Willow',
#   'last_name': 'Tree',
#   'ssn': '488-26-5727'},
#  {'_key': '842-53-5067',
#   'email': 'willow.wisp@rhyta.com',
#   'first_name': 'Willow',
#   'last_name': 'Wisp',
#   'ssn': '842-53-5067'},
#  {'_key': '887-72-7874',
#   'email': 'wtrainbelate79@rhyta.com',
#   'first_name': 'Wilma',
#   'last_name': 'Trainbelate',
#   'ssn': '887-72-7874'},
#  {'_key': '760-27-6533',
#   'email': 'wsees@armyspy.com',
#   'first_name': 'Windy',
#   'last_name': 'Sees',
#   'ssn': '760-27-6533'},
#  {'_key': '428-08-2674',
#   'email': 'wshores@dayrep.com',
#   'first_name': 'Windy',
#   'last_name': 'Shores',
#   'ssn': '428-08-2674'},
#  {'_key': '483-89-1565',
#   'email': 'wforrest12@superrito.com',
#   'first_name': 'Woodie',
#   'last_name': 'Forrest',
#   'ssn': '483-89-1565'},
#  {'_key': '882-16-5230',
#   'email': 'woodrow.aboate@rhyta.com',
#   'first_name': 'Woodrow',
#   'last_name': 'Aboate',
#   'ssn': '882-16-5230'},
#  {'_key': '662-00-8712',
#   'email': 'yolanda.smyland@armyspy.com',
#   'first_name': 'Yolanda',
#   'last_name': 'Smyland',
#   'ssn': '662-00-8712'}]

# %%
with open('seeddata/employees.json','w') as f:
    json.dump(people,f,indent=4)

# %%
from datetime import datetime, timedelta
date = datetime(2018,1,5)
for i in range(24*20):
    date_text = f"{date.year:04}-{date.month:02}-{date.day:02}"
    date_number = f"{date.year:04}{date.month:02}{date.day:02}"
    print(f"insert into pay_periods (payperiod_id, payperiod_date) values ('{date_number}','{date_text}');")
    date = date + timedelta(days=7)
# Out:
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180105','2018-01-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180112','2018-01-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180119','2018-01-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180126','2018-01-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180202','2018-02-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180209','2018-02-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180216','2018-02-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180223','2018-02-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180302','2018-03-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180309','2018-03-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180316','2018-03-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180323','2018-03-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180330','2018-03-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180406','2018-04-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180413','2018-04-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180420','2018-04-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180427','2018-04-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180504','2018-05-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180511','2018-05-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180518','2018-05-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180525','2018-05-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180601','2018-06-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180608','2018-06-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180615','2018-06-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180622','2018-06-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180629','2018-06-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180706','2018-07-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180713','2018-07-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180720','2018-07-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180727','2018-07-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180803','2018-08-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180810','2018-08-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180817','2018-08-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180824','2018-08-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180831','2018-08-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180907','2018-09-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180914','2018-09-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180921','2018-09-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20180928','2018-09-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181005','2018-10-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181012','2018-10-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181019','2018-10-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181026','2018-10-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181102','2018-11-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181109','2018-11-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181116','2018-11-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181123','2018-11-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181130','2018-11-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181207','2018-12-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181214','2018-12-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181221','2018-12-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20181228','2018-12-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190104','2019-01-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190111','2019-01-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190118','2019-01-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190125','2019-01-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190201','2019-02-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190208','2019-02-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190215','2019-02-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190222','2019-02-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190301','2019-03-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190308','2019-03-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190315','2019-03-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190322','2019-03-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190329','2019-03-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190405','2019-04-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190412','2019-04-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190419','2019-04-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190426','2019-04-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190503','2019-05-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190510','2019-05-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190517','2019-05-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190524','2019-05-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190531','2019-05-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190607','2019-06-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190614','2019-06-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190621','2019-06-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190628','2019-06-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190705','2019-07-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190712','2019-07-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190719','2019-07-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190726','2019-07-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190802','2019-08-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190809','2019-08-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190816','2019-08-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190823','2019-08-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190830','2019-08-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190906','2019-09-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190913','2019-09-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190920','2019-09-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20190927','2019-09-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191004','2019-10-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191011','2019-10-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191018','2019-10-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191025','2019-10-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191101','2019-11-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191108','2019-11-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191115','2019-11-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191122','2019-11-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191129','2019-11-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191206','2019-12-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191213','2019-12-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191220','2019-12-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20191227','2019-12-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200103','2020-01-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200110','2020-01-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200117','2020-01-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200124','2020-01-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200131','2020-01-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200207','2020-02-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200214','2020-02-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200221','2020-02-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200228','2020-02-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200306','2020-03-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200313','2020-03-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200320','2020-03-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200327','2020-03-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200403','2020-04-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200410','2020-04-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200417','2020-04-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200424','2020-04-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200501','2020-05-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200508','2020-05-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200515','2020-05-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200522','2020-05-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200529','2020-05-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200605','2020-06-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200612','2020-06-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200619','2020-06-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200626','2020-06-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200703','2020-07-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200710','2020-07-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200717','2020-07-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200724','2020-07-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200731','2020-07-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200807','2020-08-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200814','2020-08-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200821','2020-08-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200828','2020-08-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200904','2020-09-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200911','2020-09-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200918','2020-09-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20200925','2020-09-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201002','2020-10-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201009','2020-10-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201016','2020-10-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201023','2020-10-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201030','2020-10-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201106','2020-11-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201113','2020-11-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201120','2020-11-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201127','2020-11-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201204','2020-12-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201211','2020-12-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201218','2020-12-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20201225','2020-12-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210101','2021-01-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210108','2021-01-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210115','2021-01-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210122','2021-01-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210129','2021-01-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210205','2021-02-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210212','2021-02-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210219','2021-02-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210226','2021-02-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210305','2021-03-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210312','2021-03-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210319','2021-03-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210326','2021-03-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210402','2021-04-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210409','2021-04-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210416','2021-04-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210423','2021-04-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210430','2021-04-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210507','2021-05-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210514','2021-05-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210521','2021-05-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210528','2021-05-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210604','2021-06-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210611','2021-06-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210618','2021-06-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210625','2021-06-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210702','2021-07-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210709','2021-07-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210716','2021-07-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210723','2021-07-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210730','2021-07-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210806','2021-08-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210813','2021-08-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210820','2021-08-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210827','2021-08-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210903','2021-09-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210910','2021-09-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210917','2021-09-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20210924','2021-09-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211001','2021-10-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211008','2021-10-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211015','2021-10-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211022','2021-10-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211029','2021-10-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211105','2021-11-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211112','2021-11-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211119','2021-11-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211126','2021-11-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211203','2021-12-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211210','2021-12-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211217','2021-12-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211224','2021-12-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20211231','2021-12-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220107','2022-01-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220114','2022-01-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220121','2022-01-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220128','2022-01-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220204','2022-02-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220211','2022-02-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220218','2022-02-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220225','2022-02-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220304','2022-03-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220311','2022-03-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220318','2022-03-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220325','2022-03-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220401','2022-04-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220408','2022-04-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220415','2022-04-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220422','2022-04-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220429','2022-04-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220506','2022-05-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220513','2022-05-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220520','2022-05-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220527','2022-05-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220603','2022-06-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220610','2022-06-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220617','2022-06-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220624','2022-06-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220701','2022-07-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220708','2022-07-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220715','2022-07-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220722','2022-07-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220729','2022-07-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220805','2022-08-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220812','2022-08-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220819','2022-08-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220826','2022-08-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220902','2022-09-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220909','2022-09-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220916','2022-09-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220923','2022-09-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20220930','2022-09-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221007','2022-10-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221014','2022-10-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221021','2022-10-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221028','2022-10-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221104','2022-11-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221111','2022-11-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221118','2022-11-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221125','2022-11-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221202','2022-12-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221209','2022-12-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221216','2022-12-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221223','2022-12-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20221230','2022-12-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230106','2023-01-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230113','2023-01-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230120','2023-01-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230127','2023-01-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230203','2023-02-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230210','2023-02-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230217','2023-02-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230224','2023-02-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230303','2023-03-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230310','2023-03-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230317','2023-03-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230324','2023-03-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230331','2023-03-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230407','2023-04-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230414','2023-04-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230421','2023-04-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230428','2023-04-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230505','2023-05-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230512','2023-05-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230519','2023-05-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230526','2023-05-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230602','2023-06-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230609','2023-06-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230616','2023-06-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230623','2023-06-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230630','2023-06-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230707','2023-07-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230714','2023-07-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230721','2023-07-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230728','2023-07-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230804','2023-08-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230811','2023-08-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230818','2023-08-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230825','2023-08-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230901','2023-09-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230908','2023-09-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230915','2023-09-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230922','2023-09-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20230929','2023-09-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231006','2023-10-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231013','2023-10-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231020','2023-10-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231027','2023-10-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231103','2023-11-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231110','2023-11-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231117','2023-11-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231124','2023-11-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231201','2023-12-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231208','2023-12-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231215','2023-12-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231222','2023-12-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20231229','2023-12-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240105','2024-01-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240112','2024-01-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240119','2024-01-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240126','2024-01-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240202','2024-02-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240209','2024-02-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240216','2024-02-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240223','2024-02-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240301','2024-03-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240308','2024-03-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240315','2024-03-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240322','2024-03-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240329','2024-03-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240405','2024-04-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240412','2024-04-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240419','2024-04-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240426','2024-04-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240503','2024-05-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240510','2024-05-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240517','2024-05-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240524','2024-05-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240531','2024-05-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240607','2024-06-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240614','2024-06-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240621','2024-06-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240628','2024-06-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240705','2024-07-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240712','2024-07-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240719','2024-07-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240726','2024-07-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240802','2024-08-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240809','2024-08-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240816','2024-08-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240823','2024-08-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240830','2024-08-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240906','2024-09-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240913','2024-09-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240920','2024-09-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20240927','2024-09-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241004','2024-10-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241011','2024-10-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241018','2024-10-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241025','2024-10-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241101','2024-11-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241108','2024-11-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241115','2024-11-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241122','2024-11-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241129','2024-11-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241206','2024-12-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241213','2024-12-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241220','2024-12-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20241227','2024-12-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250103','2025-01-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250110','2025-01-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250117','2025-01-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250124','2025-01-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250131','2025-01-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250207','2025-02-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250214','2025-02-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250221','2025-02-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250228','2025-02-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250307','2025-03-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250314','2025-03-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250321','2025-03-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250328','2025-03-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250404','2025-04-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250411','2025-04-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250418','2025-04-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250425','2025-04-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250502','2025-05-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250509','2025-05-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250516','2025-05-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250523','2025-05-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250530','2025-05-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250606','2025-06-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250613','2025-06-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250620','2025-06-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250627','2025-06-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250704','2025-07-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250711','2025-07-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250718','2025-07-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250725','2025-07-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250801','2025-08-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250808','2025-08-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250815','2025-08-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250822','2025-08-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250829','2025-08-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250905','2025-09-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250912','2025-09-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250919','2025-09-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20250926','2025-09-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251003','2025-10-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251010','2025-10-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251017','2025-10-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251024','2025-10-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251031','2025-10-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251107','2025-11-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251114','2025-11-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251121','2025-11-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251128','2025-11-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251205','2025-12-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251212','2025-12-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251219','2025-12-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20251226','2025-12-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260102','2026-01-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260109','2026-01-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260116','2026-01-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260123','2026-01-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260130','2026-01-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260206','2026-02-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260213','2026-02-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260220','2026-02-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260227','2026-02-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260306','2026-03-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260313','2026-03-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260320','2026-03-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260327','2026-03-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260403','2026-04-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260410','2026-04-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260417','2026-04-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260424','2026-04-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260501','2026-05-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260508','2026-05-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260515','2026-05-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260522','2026-05-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260529','2026-05-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260605','2026-06-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260612','2026-06-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260619','2026-06-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260626','2026-06-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260703','2026-07-03');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260710','2026-07-10');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260717','2026-07-17');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260724','2026-07-24');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260731','2026-07-31');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260807','2026-08-07');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260814','2026-08-14');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260821','2026-08-21');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260828','2026-08-28');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260904','2026-09-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260911','2026-09-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260918','2026-09-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20260925','2026-09-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261002','2026-10-02');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261009','2026-10-09');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261016','2026-10-16');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261023','2026-10-23');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261030','2026-10-30');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261106','2026-11-06');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261113','2026-11-13');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261120','2026-11-20');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261127','2026-11-27');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261204','2026-12-04');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261211','2026-12-11');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261218','2026-12-18');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20261225','2026-12-25');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270101','2027-01-01');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270108','2027-01-08');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270115','2027-01-15');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270122','2027-01-22');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270129','2027-01-29');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270205','2027-02-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270212','2027-02-12');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270219','2027-02-19');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270226','2027-02-26');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270305','2027-03-05');
# insert into pay_periods (payperiod_id, payperiod_date) values ('20270312','2027-03-12');

# %%
def create_employee_record(eid, ssn, first_name, last_name, hire_date, jobtitle, department, pay_rate, sid=None ):
    sql = "insert into employees\n"
    sql += "\t(employee_id, employee_ssn, employee_firstname, employee_lastname, employee_hire_date, employee_jobtitle, employee_department, employee_pay_rate, employee_supervisor_employee_id )\n"
    if sid==None:
        sql += f"\t values ({eid},'{ssn}','{first_name}', '{last_name}', '{hire_date}','{jobtitle}','{department}',{pay_rate},NULL);"
    else:
        sql += f"\t values ({eid},'{ssn}','{first_name}', '{last_name}', '{hire_date}','{jobtitle}','{department}',{pay_rate},{sid});"
    return sql

def create_employee_record_sp(start_date, eid, ssn, first_name, last_name, hire_date, jobtitle, department, pay_rate, sid=None ):
    sql = "exec p_employee_upsert "
    if sid==None:
        sql += f"'{start_date}',{eid},'{ssn}','{first_name}', '{last_name}', '{hire_date}',NULL,'{jobtitle}','{department}',{pay_rate},NULL;"
    else:
        sql += f"'{start_date}',{eid},'{ssn}','{first_name}', '{last_name}', '{hire_date}',NULL,'{jobtitle}','{department}',{pay_rate}, {sid};"
    return sql

# %%
### SEED EMPLOYEES
with open('seeddata/employees.json','r') as f:
    emps = json.load(f)
    
random.shuffle(emps)
    
jobtitles = ['Store Manager', 'Department Manager', 'Sales Associate']
jobtitles_base_salary = [80000, 50000, 15]
jobtitles_delta_salary = [500, 500, 0.25]
jobtitles_buckets = [10, 13, 21]

departments = [ 'Clothing', 'Customer Service', 'Electronics', 'Hardware', 'Housewares', 'Sporting Goods', 'Toys' ]
department_cum_weights = [ 1, 1.5, 1.33, 1, 1, 1.33, 1.33]
department_sid = {}

start_date='2018-01-01'

# Seed the boss!!
sql = create_employee_record_sp(start_date,1, '123-45-6789', 'Michael', 'Fudge', '2010-04-01', 'Owner', 'Customer Service', 125000/52)
print(sql)

# Seed the store manager # 1
emp = emps.pop()
salary = jobtitles_base_salary[0] + jobtitles_delta_salary[0]*rand_normal_dist(random,jobtitles_buckets[0])
sql =create_employee_record_sp(start_date,2, emp['ssn'],emp['first_name'], emp['last_name'], '2012-05-01', jobtitles[0], 'Customer Service', salary/52, 1)
print(sql)

# Seed the store manager # 2
emp = emps.pop()
salary = jobtitles_base_salary[0] + jobtitles_delta_salary[0]*rand_normal_dist(random,jobtitles_buckets[0])
sql =create_employee_record_sp(start_date,3, emp['ssn'],emp['first_name'], emp['last_name'], '2012-07-01', jobtitles[0], 'Customer Service', salary/52, 1)
print(sql)

eid = 4
for dept in departments:
    # seed the managers
    emp = emps.pop()
    salary = jobtitles_base_salary[1] + jobtitles_delta_salary[1]*rand_normal_dist(random,jobtitles_buckets[1])
    month = random.randint(1,12)
    sql =create_employee_record_sp(start_date,eid, emp['ssn'],emp['first_name'], emp['last_name'], f'2013-{month:02}-01', 'Department Manager', dept, salary/52, random.randint(2,3))
    department_sid[dept]= eid;
    print(sql)
    eid += 1
    
    
depts = random.choices(departments, weights = department_cum_weights , k = 50)
for d in depts:
    #seed the sales associates
    emp = emps.pop()
    hourly_wage = jobtitles_base_salary[2] + jobtitles_delta_salary[2]*rand_normal_dist(random,jobtitles_buckets[2])
    month = rand_normal_dist(random,12) + 1
    year = rand_normal_dist(random,5)+ 2013
    sql =create_employee_record_sp(start_date,eid, emp['ssn'],emp['first_name'], emp['last_name'], f'{year:04}-{month:02}-01', 'Sales Associate', d, hourly_wage, department_sid[d])
    print(sql)
    eid+=1
    

# Seed one manager per department

# seed employees based on cum weighers
# Out:
# exec p_employee_upsert '2018-01-01',1,'123-45-6789','Michael', 'Fudge', '2010-04-01',NULL,'Owner','Customer Service',2403.846153846154,NULL;
# exec p_employee_upsert '2018-01-01',2,'958-76-7513','Amber', 'Wavesofgrain', '2012-05-01',NULL,'Store Manager','Customer Service',1567.3076923076924, 1;
# exec p_employee_upsert '2018-01-01',3,'047-33-0921','Joy', 'Touda-World', '2012-07-01',NULL,'Store Manager','Customer Service',1605.7692307692307, 1;
# exec p_employee_upsert '2018-01-01',4,'161-76-0353','Lisa', 'Karfurless', '2013-06-01',NULL,'Department Manager','Clothing',1019.2307692307693, 3;
# exec p_employee_upsert '2018-01-01',5,'151-91-9536','Willie', 'Pas-D'course', '2013-12-01',NULL,'Department Manager','Customer Service',990.3846153846154, 3;
# exec p_employee_upsert '2018-01-01',6,'189-32-2043','Bob', 'Enweave', '2013-02-01',NULL,'Department Manager','Electronics',1009.6153846153846, 3;
# exec p_employee_upsert '2018-01-01',7,'363-47-6635','Eileen', 'Touda-Left', '2013-10-01',NULL,'Department Manager','Hardware',1009.6153846153846, 2;
# exec p_employee_upsert '2018-01-01',8,'528-59-6392','Ty', 'Itdowne', '2013-10-01',NULL,'Department Manager','Housewares',1009.6153846153846, 2;
# exec p_employee_upsert '2018-01-01',9,'056-62-8945','Al', 'Frecso', '2013-05-01',NULL,'Department Manager','Sporting Goods',1057.6923076923076, 3;
# exec p_employee_upsert '2018-01-01',10,'826-09-9393','Val', 'Idation', '2013-05-01',NULL,'Department Manager','Toys',1019.2307692307693, 3;
# exec p_employee_upsert '2018-01-01',11,'197-38-8981','Ginger', 'Beer', '2015-05-01',NULL,'Sales Associate','Clothing',17.25, 4;
# exec p_employee_upsert '2018-01-01',12,'882-16-5230','Woodrow', 'Aboate', '2016-08-01',NULL,'Sales Associate','Electronics',17.0, 6;
# exec p_employee_upsert '2018-01-01',13,'695-25-9623','Sonny', 'Dayz', '2017-09-01',NULL,'Sales Associate','Toys',17.25, 10;
# exec p_employee_upsert '2018-01-01',14,'716-44-7134','Dan', 'Delyons', '2015-03-01',NULL,'Sales Associate','Customer Service',18.0, 5;
# exec p_employee_upsert '2018-01-01',15,'760-27-6533','Windy', 'Sees', '2015-08-01',NULL,'Sales Associate','Sporting Goods',17.5, 9;
# exec p_employee_upsert '2018-01-01',16,'065-13-3208','Ty', 'Dibol', '2015-06-01',NULL,'Sales Associate','Toys',17.5, 10;
# exec p_employee_upsert '2018-01-01',17,'203-71-1878','Myra', 'Sisdone', '2016-06-01',NULL,'Sales Associate','Sporting Goods',19.5, 9;
# exec p_employee_upsert '2018-01-01',18,'390-21-0626','Sal', 'Debote', '2015-07-01',NULL,'Sales Associate','Housewares',17.75, 8;
# exec p_employee_upsert '2018-01-01',19,'069-99-8924','Phil', 'Itall-Theweigh', '2014-07-01',NULL,'Sales Associate','Electronics',15.25, 6;
# exec p_employee_upsert '2018-01-01',20,'084-91-2754','Gail', 'Forcewynds', '2017-03-01',NULL,'Sales Associate','Electronics',17.5, 6;
# exec p_employee_upsert '2018-01-01',21,'137-92-4533','Isabelle', 'Gunnering', '2015-04-01',NULL,'Sales Associate','Hardware',16.75, 7;
# exec p_employee_upsert '2018-01-01',22,'369-37-9012','Aiden', 'Knowone', '2016-04-01',NULL,'Sales Associate','Sporting Goods',17.5, 9;
# exec p_employee_upsert '2018-01-01',23,'273-86-4648','Mike', 'Dupp', '2015-05-01',NULL,'Sales Associate','Sporting Goods',16.5, 9;
# exec p_employee_upsert '2018-01-01',24,'778-63-2969','Anita', 'Sandwich', '2016-07-01',NULL,'Sales Associate','Electronics',17.0, 6;
# exec p_employee_upsert '2018-01-01',25,'638-22-3313','Gus', 'Toffwind', '2013-08-01',NULL,'Sales Associate','Customer Service',17.25, 5;
# exec p_employee_upsert '2018-01-01',26,'415-79-2532','Anita', 'Favor', '2016-10-01',NULL,'Sales Associate','Sporting Goods',17.25, 9;
# exec p_employee_upsert '2018-01-01',27,'520-62-3750','Artie', 'Choke', '2015-07-01',NULL,'Sales Associate','Customer Service',18.0, 5;
# exec p_employee_upsert '2018-01-01',28,'489-42-0677','Carol', 'Ling', '2015-05-01',NULL,'Sales Associate','Hardware',16.25, 7;
# exec p_employee_upsert '2018-01-01',29,'685-84-9242','April', 'First', '2015-10-01',NULL,'Sales Associate','Electronics',17.25, 6;
# exec p_employee_upsert '2018-01-01',30,'098-24-5706','Sandy', 'Beeches', '2015-06-01',NULL,'Sales Associate','Hardware',15.75, 7;
# exec p_employee_upsert '2018-01-01',31,'143-95-3205','Nat', 'Tural', '2013-05-01',NULL,'Sales Associate','Hardware',17.0, 7;
# exec p_employee_upsert '2018-01-01',32,'178-66-2185','Theodore', 'Istrong', '2014-08-01',NULL,'Sales Associate','Hardware',16.75, 7;
# exec p_employee_upsert '2018-01-01',33,'093-29-8015','Hugh', 'Japple', '2016-09-01',NULL,'Sales Associate','Toys',18.0, 10;
# exec p_employee_upsert '2018-01-01',34,'041-48-3728','Misty', 'Meadows', '2014-07-01',NULL,'Sales Associate','Toys',17.5, 10;
# exec p_employee_upsert '2018-01-01',35,'321-52-1883','Doris', 'Closed', '2013-05-01',NULL,'Sales Associate','Hardware',17.0, 7;
# exec p_employee_upsert '2018-01-01',36,'140-63-5030','Ally', 'Gator', '2013-06-01',NULL,'Sales Associate','Toys',16.75, 10;
# exec p_employee_upsert '2018-01-01',37,'678-51-5677','Otto', 'Moni', '2013-06-01',NULL,'Sales Associate','Hardware',18.0, 7;
# exec p_employee_upsert '2018-01-01',38,'881-48-2053','Barb', 'Barion', '2015-07-01',NULL,'Sales Associate','Sporting Goods',17.75, 9;
# exec p_employee_upsert '2018-01-01',39,'512-08-0512','Tim', 'Idd', '2014-06-01',NULL,'Sales Associate','Sporting Goods',17.0, 9;
# exec p_employee_upsert '2018-01-01',40,'401-35-1556','Isreal', 'Difficult', '2015-02-01',NULL,'Sales Associate','Housewares',17.0, 8;
# exec p_employee_upsert '2018-01-01',41,'644-44-2632','Brayden', 'Yourhair', '2015-07-01',NULL,'Sales Associate','Electronics',18.0, 6;
# exec p_employee_upsert '2018-01-01',42,'469-19-4101','Erin', 'Detyers', '2015-09-01',NULL,'Sales Associate','Housewares',17.75, 8;
# exec p_employee_upsert '2018-01-01',43,'495-41-3173','Eura', 'Lyre', '2014-02-01',NULL,'Sales Associate','Clothing',18.75, 4;
# exec p_employee_upsert '2018-01-01',44,'989-69-3061','Candi', 'Kane', '2017-05-01',NULL,'Sales Associate','Electronics',17.5, 6;
# exec p_employee_upsert '2018-01-01',45,'520-97-0381','Sal', 'Ladd-Furdiner', '2016-04-01',NULL,'Sales Associate','Customer Service',17.25, 5;
# exec p_employee_upsert '2018-01-01',46,'991-56-0931','June', 'Nipper', '2017-05-01',NULL,'Sales Associate','Customer Service',16.5, 5;
# exec p_employee_upsert '2018-01-01',47,'817-49-5922','Sue', 'Mii', '2014-05-01',NULL,'Sales Associate','Hardware',18.25, 7;
# exec p_employee_upsert '2018-01-01',48,'842-53-5067','Willow', 'Wisp', '2014-05-01',NULL,'Sales Associate','Housewares',17.5, 8;
# exec p_employee_upsert '2018-01-01',49,'434-67-0804','Ty', 'Anott', '2016-04-01',NULL,'Sales Associate','Toys',17.75, 10;
# exec p_employee_upsert '2018-01-01',50,'112-63-5069','Pete', 'Moss', '2015-07-01',NULL,'Sales Associate','Toys',16.5, 10;
# exec p_employee_upsert '2018-01-01',51,'407-27-3291','Minnie', 'Ature-Doberman', '2014-05-01',NULL,'Sales Associate','Sporting Goods',17.25, 9;
# exec p_employee_upsert '2018-01-01',52,'151-82-5640','Jin', 'Netics', '2015-06-01',NULL,'Sales Associate','Customer Service',17.25, 5;
# exec p_employee_upsert '2018-01-01',53,'581-41-4823','Bette', 'Alott', '2013-06-01',NULL,'Sales Associate','Electronics',16.25, 6;
# exec p_employee_upsert '2018-01-01',54,'777-43-2728','Alma', 'Frienzergon', '2015-07-01',NULL,'Sales Associate','Customer Service',17.75, 5;
# exec p_employee_upsert '2018-01-01',55,'781-00-9353','Adam', 'Antium', '2016-06-01',NULL,'Sales Associate','Electronics',18.5, 6;
# exec p_employee_upsert '2018-01-01',56,'997-13-8621','Elieen', 'Onyewe', '2017-04-01',NULL,'Sales Associate','Customer Service',16.25, 5;
# exec p_employee_upsert '2018-01-01',57,'277-33-6106','Gamble', 'Moore', '2016-04-01',NULL,'Sales Associate','Customer Service',16.75, 5;
# exec p_employee_upsert '2018-01-01',58,'573-00-7626','Al', 'Kohol', '2015-08-01',NULL,'Sales Associate','Toys',17.75, 10;
# exec p_employee_upsert '2018-01-01',59,'875-41-8653','Isadore', 'Stuckopen', '2015-04-01',NULL,'Sales Associate','Clothing',17.0, 4;
# exec p_employee_upsert '2018-01-01',60,'531-22-3951','Drew', 'Apicture', '2015-02-01',NULL,'Sales Associate','Customer Service',17.5, 5;

# %%
d2 ={}
for d in depts:
    d2[d]  = d2.get(d,0) +1
    
d2
# Out:
# {'Clothing': 5,
#  'Customer Service': 12,
#  'Sporting Goods': 5,
#  'Hardware': 7,
#  'Housewares': 9,
#  'Electronics': 5,
#  'Toys': 7}

# %%
help(random.choices)
# Out:
# Help on method choices in module random:
#
# choices(population, weights=None, *, cum_weights=None, k=1) method of random.Random instance
#     Return a k sized list of population elements chosen with replacement.
#
#     If the relative weights or cumulative weights are not specified,
#     the selections are made with equal probability.
